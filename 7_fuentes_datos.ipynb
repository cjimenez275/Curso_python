# %% [markdown]
# ## Fuentes de datos
#
# Es posble encontrar datos reales de múltiples fuentes. sklearn tiene datos de juguete para comenzar, visita la pagina [sklearn-datos](https://scikit-learn.org/stable/datasets/toy_dataset.html)

# %%
import matplotlib.pyplot as plt
from sklearn import datasets
import pandas as pd

# %%
datos = datasets.load_iris()
datos;

# %% [markdown]
# Por ejemplo, explorando la página del gobierno de Colombia: [datos abiertos](https://www.datos.gov.co/) puedes encontrar muchos datos:

# %%
datos_agricola = pd.read_csv("datos/agricola.csv")

# %%
datos_agricola
# Out:
#       CÓD. \nDEP. DEPARTAMENTO CÓD. MUN.            MUNICIPIO  \
# 0              18      CAQUETA    18,205              CURILLO
# 1              18      CAQUETA    18,205              CURILLO
# 2              18      CAQUETA    18,479              MORELIA
# 3              18      CAQUETA    18,610  SAN JOSE DEL FRAGUA
# 4              18      CAQUETA    18,479              MORELIA
# ...           ...          ...       ...                  ...
# 2339           18      CAQUETA    18,205              CURILLO
# 2340           18      CAQUETA    18,205              CURILLO
# 2341           18      CAQUETA    18,205              CURILLO
# 2342           18      CAQUETA    18,205              CURILLO
# 2343           18      CAQUETA    18,205              CURILLO
#
#      GRUPO \nDE CULTIVO SUBGRUPO \nDE CULTIVO    CULTIVO  \
# 0            HORTALIZAS                ACELGA     ACELGA
# 1            HORTALIZAS                ACELGA     ACELGA
# ...
